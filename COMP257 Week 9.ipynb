# %% [markdown]
# # Naive Bayes

# %% [markdown]
# Naive Bayes methods are a set of supervised learning algorithms based on applying Bayes' theorem with the "naive" assumption of conditional independence between every pair of features given the value of the class variable. Bayes'theorem states the following relationship, given class variable $y$ and dependent feature vector $x_1$ through $x_n$,:

# %% [markdown]
# $$P(y \mid x_1, \dots, x_n) = \frac{P(y) P(x_1, \dots x_n \mid y)}
#                                  {P(x_1, \dots, x_n)}$$

# %% [markdown]
# Using the naive conditional independence assumption, we have

# %% [markdown]
# $$\begin{align}\begin{aligned}P(y \mid x_1, \dots, x_n) \propto P(y) \prod_{i=1}^{n} P(x_i \mid y)\\\Downarrow\\\hat{y} = \arg\max_y P(y) \prod_{i=1}^{n} P(x_i \mid y),\end{aligned}\end{align}$$

# %% [markdown]
# Then, we can use Maximum A Posteriori (MAP) estimation to estimate $P(y)$ and $P(x_i \mid y)$; the former is then the relative frequency of class $y$ in the training set.

# %% [markdown]
# *References*:
# H. Zhang (2004). The optimality of Naive Bayes. Proc. FLAIRS.

# %% [markdown]
# # 1 Gaussian Naive Bayes

# %% [markdown]
# **Principle** - GaussianNB implements the Gaussian Naive Bayes algorithm for classification.
# The likelihood of the features is assumed to be Gaussian:

# %% [markdown]
# $$P(x_i \mid y) = \frac{1}{\sqrt{2\pi\sigma^2_y}} \exp\left(-\frac{(x_i - \mu_y)^2}{2\sigma^2_y}\right)$$

# %% [markdown]
# The parameters $\sigma_y$ and $\mu_y$  are estimated using maximum likelihood.

# %% [markdown]
# **Example** - The training data is generated as follows:

# %%
import numpy as np
X = np.array([[-1, -1], [-2, -1], [-3, -2], [1, 1], [2, 1], [3, 2]])
Y = np.array([1, 1, 1, 2, 2, 2])

# %% [markdown]
# **Q1**: Training a GaussianNB model:
#
# Key Parameters in GaussianNB:
# **priors**: array-like, shape (n_classes,)
# &emsp;&emsp;Prior probabilities of the classes. If specified the priors are not adjusted according to the data.
# **var_smoothing**: float, optional (default=1e-9)
# &emsp;&emsp;Portion of the largest variance of all features that is added to variances for calculation stability.
#
#
# Here, we use the default parameter setting.

# %%
[code...]

# %% [markdown]
# **Q2**: Predict the label of a data [-0.8,-1]:

# %%
[code...]

# %% [markdown]
# # 2 MultinomialNB

# %% [markdown]
# The multinomial Naive Bayes classifier is suitable for classification with discrete features (e.g., word counts for text classification).

# %% [markdown]
# *References*
# C.D. Manning, P. Raghavan and H. Schuetze (2008). Introduction to Information Retrieval. Cambridge University Press, pp. 234-265. http://nlp.stanford.edu/IR-book/html/htmledition/naive-bayes-text-classification-1.html

# %% [markdown]
# **Principle** - The distribution is parametrized by vectors $\theta_y = (\theta_{y1},\ldots,\theta_{yn})$  for each class $y$, where $n$ is the number of features and $\theta_{yi}$ is the probability $P(x_i \mid y)$ of feature $i$ appearing in a sample belonging to class $y$.
#
# The parameters $\theta_y$  is estimated by a smoothed version of maximum likelihood, i.e. relative frequency counting: $$\hat{\theta}_{yi} = \frac{ N_{yi} + \alpha}{N_y + \alpha n}$$
# where $N_{yi} = \sum_{x \in T} x_i$  is the number of times feature $i$  appears in a sample of class $y$ in the training set $T$, and $N_{y} = \sum_{i=1}^{n} N_{yi}$ is the total count of all features for class $y$.
#
# The smoothing priors $\alpha \ge 0$ accounts for features not present in the learning samples and prevents zero probabilities in further computations. Setting $\alpha = 1$ is called Laplace smoothing, while $\alpha < 1$ is called Lidstone smoothing.

# %% [markdown]
# **Example** - The training data is generated as follows:

# %%
import numpy as np
X = np.random.randint(5, size=(6, 100))
y = np.array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# **Q3**: Training a MultinomialNB model:

# %% [markdown]
# Key Parameters in MultinomialNB:
# **alpha**: float, optional (default=1.0):
# &emsp;&emsp;Additive (Laplace/Lidstone) smoothing parameter (0 for no smoothing).
# **fit_prior**: boolean:
# &emsp;&emsp;Whether to learn class prior probabilities or not. If false, a uniform prior will be used.
#
#
# Here, we use the default parameter setting.

# %%
[code...]

# %% [markdown]
# **Q4**: Predict the label of a data X[2:3]:

# %%
[code...]

# %% [markdown]
# # 3 Process on 'Iris' Data

# %% [markdown]
# In Week 8, we have studied how to use KNN algorithm to do classification task on 'iris' data. Here, we are going to employ the GaussianNB to conduct the same task.

# %% [markdown]
# **Q5**：Load the data and check the type of the features: Whether they are continued or discrete?
# &nbsp; &nbsp; 1.If the answer to **Q5** is continued then employing the GaussianNB model, otherwise training a MultinomialNB. The default parameter setting is applied.
# &nbsp; &nbsp; 2.When training the model, 70% of data is used as the training set with the rest as the test set.

# %%
[code...]

# %% [markdown]
# **Q6**：Report the accuracy result on the training and test data, respectively:

# %%
[code...]

# %% [markdown]
# # 4 Weather Prediction

# %%
from IPython.display import Image
Image(filename='Weather.png',width = "600",height = "300")

# %% [markdown]
# Here we have our data, which comprises the day, outlook, humidity, and wind conditions. The final column is 'Play,' i.e., can we play outside, which we have to predict.

# %% [markdown]
# **Q7**：Load the CSV data [Weather.CSV] from iLearn and check the type of the features: Whether they are continued or discrete?
# &nbsp; &nbsp; 1.If the answer to **Q7** is continued then employing the GaussianNB model, otherwise training a MultinomialNB. The default parameter setting is applied.
# &nbsp; &nbsp; 2.When training the model, 70% of data is used as the training set with the rest as the test set.

# %%
[code...]

# %% [markdown]
# **Q8**：Report the accuracy result on the training and test data, respectively:

# %%
[code...]
